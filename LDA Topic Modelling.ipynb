# %%
import numpy as np
import pandas as pd

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en.stop_words import STOP_WORDS
# import en_core_web_lg

from tqdm import tqdm_notebook as tqdm
from pprint import pprint

# %%
df = pd.read_csv('tweets.csv')
docs = df['tweets']

# %%
docs
# Out:
# 0        ENGLISH TRANSLATION: 'A MESSAGE TO THE TRUTHFU...
# 1        ENGLISH TRANSLATION: SHEIKH FATIH AL JAWLANI '...
# 2        ENGLISH TRANSLATION: FIRST AUDIO MEETING WITH ...
# 3        ENGLISH TRANSLATION: SHEIKH NASIR AL WUHAYSHI ...
# 4        ENGLISH TRANSLATION: AQAP: 'RESPONSE TO SHEIKH...
# 5        THE SECOND CLIP IN A DA'WAH SERIES BY A SOLDIE...
# 6        ENGLISH TRANSCRIPT : OH MURABIT! : http://t.co...
# 7        ENGLISH TRANSLATION: 'A COLLECTION OF THE WORD...
# 8        Aslm Please share our new account after the pr...
# 9        ENGLISH TRANSLATION: AQAP STATEMENT REGARDING ...
# 10       @KhalidMaghrebi @seifulmaslul123 @CheerLeadUni...
# 11       NEW LINK, AFTER PREVIOUS ONE TAKEN DOWN:AQAP-'...
# 12       ENGLISH TRANSLATION- SHEIKH ABU HASAN AL KUWAI...
# 13       SHEIKH ABU HASSAN AL KUWAITI (HA): ADVICE OF N...
# 14       @IbnNabih1 @MuwMedia @Dawlat_islam7 Not transl...
# 15       Aslm, anybody translating the new JN video? Wi...
# 16       @IbnNabih1 @KhalidMaghrebi_ @MuwMedia @Polder_...
# 17       @IbnNabih1 @abuw_ukasyah @polder_mujaahid @Abu...
# 18       @AbdirahmanBash2 @KhalidMaghrebi_ @IbnNabih1 @...
# 19       @AbdirahmanBash2 @KhalidMaghrebi_ @IbnNabih1 @...
# 20       @AbdirahmanBash2 @KhalidMaghrebi_ @IbnNabih1 @...
# 21       NEW links for #JN Video - ENG Subs: The Path o...
# 22       DOWNLOAD #JN Video With English Subtitles: The...
# 23       Video by @ansardeenfront with Eng Subtitles: '...
# 24       ENGLISH TRANSLATION: A Pamphlet Released By #J...
# 25       Aslm, anybody translating the new audio of She...
# 26       @abuhamzaneh @50W30 @JN_Irhabiyya_97 @Aba_M0ha...
# 27       RT @GIIMedia_CH004: Rules Of Imarah Part2 - Co...
# 28       ENGLISH TRANSLATION: Dialogue with Sheikh Tart...
# 29       ‍‌‌‌‌‍‌‌‌🔻‌‌[ الإثنين  1436/9/19 هـ ]‍‌‌‌‌‍‍‍‍...
#                                ...
# 17379    RT @_The_Hikmah_: #IbnAlQayyim #Allah Ta`Aala\...
# 17380    Local Source: Daily and Heavy Clashes between ...
# 17381    #Breaking\n#IslamicState \n\n#Fallujah \n#Euro...
# 17382    HUGE\n\nAt least 300 Irani IRCG Soldiers were ...
# 17383    RT @anti_shirkkkk: "A single expedition in the...
# 17384    #Breaking\n#IslamicState Forces assault Iraqi ...
# 17385    RT @PalmyraPioneer: These images of the massac...
# 17386    @MehdiTh2 @_Darmouss @PeigneACheveux j'aimerai...
# 17387    3 Martyrdom bombers detonate their Xplosive be...
# 17388    @_Darmouss une légende de twitter, il a rejoin...
# 17389    #Breaking \n#IslamicState \n  || 3 Martydom bo...
# 17390    @HadjSarrasins pas mal ce tweet toi aussi tu v...
# 17391    RT @HadjSarrasins: Mais qui a envie d'entendre...
# 17392    #AmaqAgency so far 9 Iraqi hummers, an autocan...
# 17393    RT @RamiAlLolah: #Exclusive Photo: #Hezbollah ...
# 17394    According to the SOHR, JAN is responsible of t...
# 17395    Notice that the fighter who trample the bodies...
# 17396    The local commander of Ahrar Al Sham appears i...
# 17397    RT @SimNasr: #Syria: Who was Mustapha #Badredd...
# 17398    RT @SimNasr: Erratum shiaa Afghan fighters who...
# 17399    RT @jdanteff: Aamaq footage:\nDestruction of I...
# 17400    Heavy battles going on in Al Karmah northeast ...
# 17401    "Is the Islamic State trying  to draw Turkey i...
# 17402    9 Hummers an autocannon and a field artillery ...
# 17403    #LT Notice that this possible strategy was men...
# 17404    #Breaking\n#IslamicState \n#AmaqAgency \n\n#Fr...
# 17405    #Breaking\n\n Iraqi forces bulldozer destroyed...
# 17406    #Breaking \n#AmaqAgency \n#IslamicState \n\n#E...
# 17407    #PhotoReport \n#WilayatDimasiqh \n\n📷The Condu...
# 17408    #AmaqAgency Destroyed and burning Iraqi Forces...
# Name: tweets, Length: 17409, dtype: object

# %%
import re
def label_lng (row):
    if "ENGLISH TRANSLATION:" in row['tweets']:
        return 'ar'
    elif re.match (r'[\u0621-\u064A]', row['tweets']):
        return 'ar'
    else:
        return 'en'
    
def check_readable (row):
    if len(row["txt"]) > 2 and row["lng"] == "en":
        return 1
    else: return 0
    
    
df['lng'] = df.apply (lambda row: label_lng(row), axis=1)
df['txt'] = df['tweets'].str.replace('http\S+|www.\S+', '', case=False)
df['txt'] = df['txt'].str.replace('(\#|\@)([\w]+)', '', case=False, regex=True)

df['txt'] = df['txt'].apply(lambda x: x.replace("ENGLISH TRANSLATION: ", ''))

df['txt'] = df['txt'].str.replace('\n', ' ', case=False, regex=True)
df['txt'] = df['txt'].str.replace('\s+', ' ', case=False, regex=True)
df['rb'] = df.apply (lambda row: check_readable(row), axis=1)

# %%
df.iloc[500]
# Out:
# name                                                  The Witnesser
# username                                              Bajwa47online
# description       The Dust Will Never Settle Down  \n           ...
# location                                                        NaN
# followers                                                       427
# numberstatuses                                                 1953
# time                                               10/25/2015 17:10
# tweets            @Jihad67a akhi, ya'ni now, after punishment in...
# lng                                                              en
# txt                akhi, ya'ni now, after punishment in dunya, t...
# rb                                                                1
# Name: 500, dtype: object

# %%
nlp= spacy.load("en")

# %%
from spacy.lang.en.stop_words import STOP_WORDS
stop_list = []

nlp.Defaults.stop_words.update(stop_list)


# # Iterates over the words in the stop words list and resets the "is_stop" flag.
# for word in STOP_WORDS:
#     lexeme = nlp.vocab[word]
#     lexeme.is_stop = True
for word in STOP_WORDS:
    lexeme = nlp.vocab[word]
    lexeme.is_stop = True

# %%
def lemmatizer(doc):
    # This takes in a doc of tokens from the NER and lemmatizes them. 
    # Pronouns (like "I" and "you" get lemmatized to '-PRON-', so I'm removing those.
    doc = [token.lemma_ for token in doc if token.lemma_ != '-PRON-']
    doc = u' '.join(doc)
    return nlp.make_doc(doc)
    
def remove_stopwords(doc):
    # This will remove stopwords and punctuation.
    # Use token.text to return strings, which we'll need for Gensim.
    doc = [token.text for token in doc if token.is_stop != True and token.is_punct != True]
    return doc

# The add_pipe function appends our functions to the default pipeline.
nlp.add_pipe(lemmatizer,name='lemmatizer',after='ner')
nlp.add_pipe(remove_stopwords, name="stopwords", last=True)

# %%
sel = df.loc[df['rb'] == 1, 'txt']

# %%
doc_list = []
# Iterates through each article in the corpus.
for doc in tqdm(sel):
    # Passes that article through the pipeline and adds to a new list.
    pr = nlp(doc)
    doc_list.append(pr)
# Out:
# HBox(children=(IntProgress(value=0, max=16803), HTML(value='')))

# %%
# 17222 texts
# 16 803
doc_list[9]
# Out:
# ['  ', 'half', 'way', 'day', 'inshallah', 'busy']

# %%
words = corpora.Dictionary(doc_list)
corpus = [words.doc2bow(doc) for doc in doc_list]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=words,
                                           num_topics=10, 
                                           random_state=2,
                                           update_every=1,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
pprint(lda_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.029*"|" + 0.026*"في" + 0.020*"من" + 0.015*"IED" + 0.014*"📷" + '
#   '0.013*"egyptian" + 0.011*"على" + 0.010*"  " + 0.008*"▪" + 0.007*"الدولة"'),
#  (1,
#   '0.046*"Al" + 0.019*"state" + 0.018*"Nusra" + 0.018*"islamic" + 0.015*"ally" '
#   '+ 0.015*"Ahrar" + 0.013*"Sham" + 0.010*"Abu" + 0.008*"al" + 0.008*"||"'),
#  (2,
#   '0.018*"position" + 0.018*"east" + 0.016*"south" + 0.015*"😂" + '
#   '0.014*"kurdish" + 0.013*"eastern" + 0.013*"Northern" + 0.012*"dozen" + '
#   '0.012*"Fallujah" + 0.012*"militia"'),
#  (3,
#   '0.017*"release" + 0.015*"Abu" + 0.014*"Al" + 0.013*"apostate" + '
#   '0.011*"member" + 0.010*"Qaeda" + 0.009*"link" + 0.008*"pro" + '
#   '0.008*"gathering" + 0.008*"lol"'),
#  (4,
#   '0.027*"RT" + 0.012*"الله" + 0.009*"body" + 0.009*"Shia" + 0.009*"10" + '
#   '0.009*"account" + 0.008*"massive" + 0.007*"government" + 0.007*"ask" + '
#   '0.007*"footage"'),
#  (5,
#   '0.126*"  " + 0.026*"ISIS" + 0.026*"RT" + 0.016*"State" + 0.016*"Islamic" + '
#   '0.014*"Assad" + 0.013*"amp" + 0.013*"fight" + 0.012*"Allah" + '
#   '0.011*"people"'),
#  (6,
#   '0.100*"RT" + 0.041*"kill" + 0.016*"al" + 0.016*"attack" + 0.016*"amp" + '
#   '0.015*"near" + 0.014*"soldier" + 0.014*"  " + 0.013*"army" + 0.013*"today"'),
#  (7,
#   '0.039*"  " + 0.029*"de" + 0.017*"la" + 0.012*"les" + 0.011*"un" + '
#   '0.011*"des" + 0.010*"je" + 0.009*"brother" + 0.009*"Allah" + 0.009*"en"'),
#  (8,
#   '0.025*"North" + 0.016*"reportedly" + 0.015*"field" + 0.013*"South" + '
#   '0.012*"pilot" + 0.012*"announce" + 0.011*"barrack" + 0.010*"security" + '
#   '0.008*"fuck" + 0.008*"bin"'),
#  (9,
#   '0.025*"Aleppo" + 0.024*"le" + 0.020*"help" + 0.012*"pas" + 0.010*"1" + '
#   '0.009*"Coalition" + 0.008*"cry" + 0.007*"plan" + 0.006*"great" + '
#   '0.006*"2/2"')]

# %%
def get_topic(intext):
    bow = nlp(intext)
    lis = lda_model.get_document_topics(words.doc2bow(bow))
    res  = max(lis, key=lambda x:x[1])
    return res[0]

# %%
# sel
get_topic(sel.iloc[10])
# Out:
# 5

# %%
df['topic'] = df.apply (lambda row: get_topic(row["txt"]), axis=1)

# %%
df[['username', 'txt', 'rb', 'topic']]
# Out:
#               username                                                txt  rb  \
# 0      GunsandCoffee70  'A MESSAGE TO THE TRUTHFUL IN SYRIA - SHEIKH A...   0
# 1      GunsandCoffee70  SHEIKH FATIH AL JAWLANI 'FOR THE PEOPLE OF INT...   0
# 2      GunsandCoffee70  FIRST AUDIO MEETING WITH SHEIKH FATIH AL JAWLA...   0
# 3      GunsandCoffee70  SHEIKH NASIR AL WUHAYSHI (HA), LEADER OF AQAP:...   0
# 4      GunsandCoffee70  AQAP: 'RESPONSE TO SHEIKH BAGHDADIS STATEMENT ...   0
# 5      GunsandCoffee70  THE SECOND CLIP IN A DA'WAH SERIES BY A SOLDIE...   1
# 6      GunsandCoffee70                ENGLISH TRANSCRIPT : OH MURABIT! :    1
# 7      GunsandCoffee70  'A COLLECTION OF THE WORDS OF THE U'LAMA REGAR...   0
# 8      GunsandCoffee70  Aslm Please share our new account after the pr...   1
# 9      GunsandCoffee70  AQAP STATEMENT REGARDING THE BLESSED RAID IN F...   0
# 10     GunsandCoffee70                                                      0
# 11     GunsandCoffee70  NEW LINK, AFTER PREVIOUS ONE TAKEN DOWN:AQAP-'...   1
# 12     GunsandCoffee70  ENGLISH TRANSLATION- SHEIKH ABU HASAN AL KUWAI...   1
# 13     GunsandCoffee70  SHEIKH ABU HASSAN AL KUWAITI (HA): ADVICE OF N...   1
# 14     GunsandCoffee70                         Not translating it either.   1
# 15     GunsandCoffee70  Aslm, anybody translating the new JN video? Wi...   1
# 16     GunsandCoffee70   So we will translate it then inshallah let us...   1
# 17     GunsandCoffee70   half way through, a few more days inshallah, ...   1
# 18     GunsandCoffee70   Aslm, we have completed the translation with ...   1
# 19     GunsandCoffee70   reports and words of the Syrian people, will ...   1
# 20     GunsandCoffee70      inshallah. Should we still finish it, or not?   1
# 21     GunsandCoffee70  NEW links for Video - ENG Subs: The Path of Sa...   1
# 22     GunsandCoffee70  DOWNLOAD Video With English Subtitles: The Pat...   1
# 23     GunsandCoffee70  Video by with Eng Subtitles: 'Save Aleppo' WAT...   1
# 24     GunsandCoffee70  A Pamphlet Released By Regarding Group of ‘Daw...   0
# 25     GunsandCoffee70  Aslm, anybody translating the new audio of She...   1
# 26     GunsandCoffee70                         Aslm, Will do it inshallah   1
# 27     GunsandCoffee70  RT : Rules Of Imarah Part2 - Conditions of Ima...   1
# 28     GunsandCoffee70              Dialogue with Sheikh Tartoosi Part 2    0
# 29     AbuLaythAlHindi  ‍‌‌‌‌‍‌‌‌🔻‌‌[ الإثنين 1436/9/19 هـ ]‍‌‌‌‌‍‍‍‍‌...   1
# ...                ...                                                ...  ..
# 17379       melvynlion                                      RT : Ta`Aala    1
# 17380      Nidalgazaui  Local Source: Daily and Heavy Clashes between ...   1
# 17381          nvor85j                                                      0
# 17382      Nidalgazaui  HUGE At least 300 Irani IRCG Soldiers were kil...   1
# 17383   Mountainjjoool  RT : "A single expedition in the afternoon or ...   1
# 17384          nvor85j   Forces assault Iraqi Army nd Popular Mobiliza...   1
# 17385      Nidalgazaui  RT : These images of the massacre perpetrated ...   1
# 17386    Uncle_SamCoco                        j'aimerai bien savoir aussi   1
# 17387          nvor85j  3 Martyrdom bombers detonate their Xplosive be...   1
# 17388    Uncle_SamCoco   une légende de twitter, il a rejoint le Panth...   1
# 17389          nvor85j   || 3 Martydom bombers detonate their xplosive...   1
# 17390    Uncle_SamCoco   pas mal ce tweet toi aussi tu vas percer comm...   1
# 17391    Uncle_SamCoco  RT : Mais qui a envie d'entendre quelqu'un fai...   1
# 17392           ro34th   so far 9 Iraqi hummers, an autocannon, and a ...   1
# 17393        lNSlDEWAR  RT : Photo: Mustafa Badreddine moments after a...   1
# 17394    Uncle_SamCoco  According to the SOHR, JAN is responsible of t...   1
# 17395    Uncle_SamCoco  Notice that the fighter who trample the bodies...   1
# 17396    Uncle_SamCoco  The local commander of Ahrar Al Sham appears i...   1
# 17397    Uncle_SamCoco   RT : : Who was Mustapha , the commander killed?    1
# 17398    Uncle_SamCoco  RT : Erratum shiaa Afghan fighters who die in ...   1
# 17399   Mountainjjoool  RT : Aamaq footage: Destruction of Iraqi force...   1
# 17400   Mountainjjoool  Heavy battles going on in Al Karmah northeast ...   1
# 17401    Uncle_SamCoco  "Is the Islamic State trying to draw Turkey in...   1
# 17402          nvor85j  9 Hummers an autocannon and a field artillery ...   1
# 17403    Uncle_SamCoco   Notice that this possible strategy was mentio...   1
# 17404          nvor85j                                                      0
# 17405          nvor85j   Iraqi forces bulldozer destroyed by guided mi...   1
# 17406          nvor85j                                                      0
# 17407          nvor85j         📷The Conduct of Battles inYarmouk Camp in    1
# 17408           ro34th   Destroyed and burning Iraqi Forces Tank in Ju...   1
#
#        topic
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# 5          9
# 6          3
# 7          5
# 8          4
# 9          6
# 10         6
# 11         5
# 12         1
# 13         1
# 14         5
# 15         4
# 16         5
# 17         5
# 18         5
# 19         5
# 20         5
# 21         2
# 22         6
# 23         8
# 24         5
# 25         2
# 26         5
# 27         6
# 28         6
# 29         8
# ...      ...
# 17379      6
# 17380      6
# 17381      6
# 17382      6
# 17383      5
# 17384      2
# 17385      6
# 17386      7
# 17387      2
# 17388      7
# 17389      4
# 17390      7
# 17391      7
# 17392      6
# 17393      6
# 17394      1
# 17395      5
# 17396      4
# 17397      6
# 17398      5
# 17399      6
# 17400      6
# 17401      5
# 17402      2
# 17403      5
# 17404      6
# 17405      6
# 17406      6
# 17407      0
# 17408      6
#
# [17409 rows x 4 columns]

# %%
df.to_csv('result.csv')
